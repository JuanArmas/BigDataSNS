# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanArmas/BigDataSNS/blob/main/Actividad_3_2_Iris_NaiveBayes_JuanArmas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Juan Airam Armas Alemán.
#
# Github:

# %% [markdown]
# <h1> Para el dataset IRIS

# %% [markdown]
# ## Clasificación CategoricalNB

# %%
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import CategoricalNB
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
from sklearn.utils.multiclass import unique_labels

# Cargar el conjunto de datos Iris
iris = sns.load_dataset('iris')
X_iris = iris.drop('species', axis=1)
y_iris = iris['species']
Xtrain, Xtest, ytrain, ytest = train_test_split(X_iris, y_iris, test_size=0.33, random_state=1)

# Instanciar el modelo y realizar el entrenamiento
model = CategoricalNB()
model.fit(Xtrain, ytrain)

# Realizar predicciones y calcular la precisión
y_model = model.predict(Xtest)
accuracy = accuracy_score(ytest, y_model)
print("Precisión del modelo:", accuracy)

# Función para mostrar la matriz de confusión
def plot_confusion_matrix(y_true, y_pred, classes, normalize=False, title=None, cmap=plt.cm.Blues, titleSup=None):
    cm = confusion_matrix(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Matriz de confusión normalizada:")
    else:
        print('Matriz de confusión sin normalizar:')
    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=classes, yticklabels=classes, title=title, ylabel='Etiqueta real', xlabel='Etiqueta predicha')
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt), ha="center", va="center", color="white" if cm[i, j] > thresh else "black")

    total_accuracy = accuracy_score(y_true, y_pred)
    ax.text(0.5, -0.15, f"\n\nPrecisión total: {total_accuracy:.2f}", ha="center", va="top", transform=ax.transAxes, fontsize=12)

    fig.tight_layout()
    fig.suptitle(titleSup, fontsize=16, y=1, ha='center')
    plt.show()

# Visualizar la matriz de confusión
clases_iris = np.array(['setosa', 'versicolor', 'virginica'])
plot_confusion_matrix(ytest, y_model, classes=clases_iris, normalize=False, title='Matriz de confusión', titleSup='CategoricalNB')
# Out:
# Precisión del modelo: 0.98
# Matriz de confusión sin normalizar:
# [[17  0  0]
#  [ 0 18  1]
#  [ 0  0 14]]

# %% [markdown]
# ## Clasificador GaussianNB

# %%
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
from sklearn.utils.multiclass import unique_labels

# Cargar el conjunto de datos Iris
iris = sns.load_dataset('iris')
X_iris = iris.drop('species', axis=1)
y_iris = iris['species']
Xtrain, Xtest, ytrain, ytest = train_test_split(X_iris, y_iris, test_size=0.33, random_state=1)

# Instanciar el modelo y realizar el entrenamiento
model = GaussianNB()
model.fit(Xtrain, ytrain)

# Realizar predicciones y calcular la precisión
y_model = model.predict(Xtest)
accuracy = accuracy_score(ytest, y_model)
print("Precisión del modelo:", accuracy)

# Función para mostrar la matriz de confusión
def plot_confusion_matrix(y_true, y_pred, classes, normalize=False, title=None, cmap=plt.cm.Blues, titleSup=None):
    cm = confusion_matrix(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Matriz de confusión normalizada:")
    else:
        print('Matriz de confusión sin normalizar:')
    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=classes, yticklabels=classes, title=title, ylabel='Etiqueta real', xlabel='Etiqueta predicha')
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt), ha="center", va="center", color="white" if cm[i, j] > thresh else "black")

    total_accuracy = accuracy_score(y_true, y_pred)
    ax.text(0.5, -0.15, f"\n\nPrecisión total: {total_accuracy:.2f}", ha="center", va="top", transform=ax.transAxes, fontsize=12)

    fig.tight_layout()
    fig.suptitle(titleSup, fontsize=16, y=1, ha='center')
    plt.show()

# Visualizar la matriz de confusión
clases_iris = np.array(['setosa', 'versicolor', 'virginica'])
plot_confusion_matrix(ytest, y_model, classes=clases_iris, normalize=False, title='Matriz de confusión', titleSup='GaussianNB')
# Out:
# Precisión del modelo: 0.94
# Matriz de confusión sin normalizar:
# [[17  0  0]
#  [ 0 17  2]
#  [ 0  1 13]]

# %% [markdown]
# ## Clasificador ComplementNB

# %%
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import ComplementNB
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
from sklearn.utils.multiclass import unique_labels

# Cargar el conjunto de datos Iris
iris = sns.load_dataset('iris')
X_iris = iris.drop('species', axis=1)
y_iris = iris['species']
Xtrain, Xtest, ytrain, ytest = train_test_split(X_iris, y_iris, test_size=0.33, random_state=1)

# Instanciar el modelo y realizar el entrenamiento
model = ComplementNB()
model.fit(Xtrain, ytrain)

# Realizar predicciones y calcular la precisión
y_model = model.predict(Xtest)
accuracy = accuracy_score(ytest, y_model)
print("Precisión del modelo:", accuracy)

# Función para mostrar la matriz de confusión
def plot_confusion_matrix(y_true, y_pred, classes, normalize=False, title=None, cmap=plt.cm.Blues, titleSup=None):
    cm = confusion_matrix(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Matriz de confusión normalizada:")
    else:
        print('Matriz de confusión sin normalizar:')
    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=classes, yticklabels=classes, title=title, ylabel='Etiqueta real', xlabel='Etiqueta predicha')
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt), ha="center", va="center", color="white" if cm[i, j] > thresh else "black")

    total_accuracy = accuracy_score(y_true, y_pred)
    ax.text(0.5, -0.15, f"\n\nPrecisión total: {total_accuracy:.2f}", ha="center", va="top", transform=ax.transAxes, fontsize=12)

    fig.tight_layout()
    fig.suptitle(titleSup, fontsize=16, y=1, ha='center')
    plt.show()

# Visualizar la matriz de confusión
clases_iris = np.array(['setosa', 'versicolor', 'virginica'])
plot_confusion_matrix(ytest, y_model, classes=clases_iris, normalize=False, title='Matriz de confusión', titleSup='ComplementNB')
# Out:
# Precisión del modelo: 0.62
# Matriz de confusión sin normalizar:
# [[17  0  0]
#  [ 0  0 19]
#  [ 0  0 14]]

# %% [markdown]
# ## Clasificador BernoulliNB

# %%
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
from sklearn.utils.multiclass import unique_labels

# Cargar el conjunto de datos Iris
iris = sns.load_dataset('iris')
X_iris = iris.drop('species', axis=1)
y_iris = iris['species']
Xtrain, Xtest, ytrain, ytest = train_test_split(X_iris, y_iris, test_size=0.33, random_state=1)

# Instanciar el modelo y realizar el entrenamiento
model = BernoulliNB()
model.fit(Xtrain, ytrain)

# Realizar predicciones y calcular la precisión
y_model = model.predict(Xtest)
accuracy = accuracy_score(ytest, y_model)
print("Precisión del modelo:", accuracy)

# Función para mostrar la matriz de confusión
def plot_confusion_matrix(y_true, y_pred, classes, normalize=False, title=None, cmap=plt.cm.Blues, titleSup=None):
    cm = confusion_matrix(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Matriz de confusión normalizada:")
    else:
        print('Matriz de confusión sin normalizar:')
    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=classes, yticklabels=classes, title=title, ylabel='Etiqueta real', xlabel='Etiqueta predicha')
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt), ha="center", va="center", color="white" if cm[i, j] > thresh else "black")

    total_accuracy = accuracy_score(y_true, y_pred)
    ax.text(0.5, -0.15, f"\n\nPrecisión total: {total_accuracy:.2f}", ha="center", va="top", transform=ax.transAxes, fontsize=12)

    fig.tight_layout()
    fig.suptitle(titleSup, fontsize=16, y=1, ha='center')
    plt.show()

# Visualizar la matriz de confusión
clases_iris = np.array(['setosa', 'versicolor', 'virginica'])
plot_confusion_matrix(ytest, y_model, classes=clases_iris, normalize=False, title='Matriz de confusión', titleSup='BernoulliNB')
# Out:
# Precisión del modelo: 0.28
# Matriz de confusión sin normalizar:
# [[ 0  0 17]
#  [ 0  0 19]
#  [ 0  0 14]]

# %% [markdown]
# ## Clasificador MultinomialNB

# %%
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
from sklearn.utils.multiclass import unique_labels

# Cargar el conjunto de datos Iris
iris = sns.load_dataset('iris')
X_iris = iris.drop('species', axis=1)
y_iris = iris['species']
Xtrain, Xtest, ytrain, ytest = train_test_split(X_iris, y_iris, test_size=0.33, random_state=1)

# Instanciar el modelo y realizar el entrenamiento
model = MultinomialNB()
model.fit(Xtrain, ytrain)

# Realizar predicciones y calcular la precisión
y_model = model.predict(Xtest)
accuracy = accuracy_score(ytest, y_model)
print("Precisión del modelo:", accuracy)

# Función para mostrar la matriz de confusión
def plot_confusion_matrix(y_true, y_pred, classes, normalize=False, title=None, cmap=plt.cm.Blues, titleSup=None):
    cm = confusion_matrix(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Matriz de confusión normalizada:")
    else:
        print('Matriz de confusión sin normalizar:')
    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=classes, yticklabels=classes, title=title, ylabel='Etiqueta real', xlabel='Etiqueta predicha')
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt), ha="center", va="center", color="white" if cm[i, j] > thresh else "black")

    total_accuracy = accuracy_score(y_true, y_pred)
    ax.text(0.5, -0.15, f"\n\nPrecisión total: {total_accuracy:.2f}", ha="center", va="top", transform=ax.transAxes, fontsize=12)

    fig.tight_layout()
    fig.suptitle(titleSup, fontsize=16, y=1, ha='center')
    plt.show()

    # Visualizar la matriz de confusión
clases_iris = np.array(['setosa', 'versicolor', 'virginica'])
plot_confusion_matrix(ytest, y_model, classes=clases_iris, normalize=False, title='Matriz de confusión', titleSup='MultinomialNB')
# Out:
# Precisión del modelo: 0.64
# Matriz de confusión sin normalizar:
# [[17  0  0]
#  [ 0  1 18]
#  [ 0  0 14]]
